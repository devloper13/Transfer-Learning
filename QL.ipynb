# %%
import numpy as np
from copy import deepcopy
from tqdm import tqdm
import matplotlib.pyplot as plt
import pickle

# %%
##Environment
class GridWorld:
    def __init__(self, height = 50, width = 50, n_c = 1, n_o = 1):
        self.wd = width
        self.ht = height
        self.n_c = n_c            # no. of classes
        self.n_o = n_o            # no. of objects  (n_c <= n_o)
        self.reward = [-1, 1]     # range of rewards
        self.start_coord = (0, 0)
        self.goal_coord = (height-1, width-1)
        self.x_g = height-1        # goal x-coord
        self.x_g = width-1         # goal y-coord
        self.r_g = 1               # goal reward
        self.D = 100 + n_o
        self.d = n_c + 1
        '''
        UP: 0
        RIGHT: 1
        DOWN: 2
        LEFT: 3
        '''
        self.actions = [0, 1, 2, 3]
        #self.x_s, self.y_s = self.start_coord

        self.object_coord = []
        self.object_class = []
        self.class_reward = {}
        self.objects_so_far = [0] * self.n_o

        self.generate_objects()    # Done once
        
        self.assign_classes()
        self.generate_class_reward()

    def generate_objects(self):
        n_o = self.n_o
        while n_o:
            object_x = np.random.randint(self.wd)
            object_y = np.random.randint(self.ht)
            if((object_x,object_y) not in self.object_coord):
                self.object_coord.append((object_x,object_y))
                n_o -= 1
  
    def assign_classes (self):
        self.object_class = np.random.randint(0, self.n_c, size = self.n_o)
 
    def generate_class_reward(self):
        for i in range(0, self.n_c):
            self.class_reward[i] = np.random.uniform(self.reward[0], self.reward[1])

    def reset(self):
        self.cur_pos_x, self.cur_pos_y = self.start_coord
        self.object_so_far = [0] * self.n_o
        self.generate_class_reward()
        return self.start_coord

    def render(self):
        for i in range(self.wd):
            for j in range(self.ht):
                if (i, j) in self.object_coord:
                    print(self.object_class[self.object_coord.index((i, j))], end = "")
                else:
                    print("*",end = "")
            print("")
            
    def show_class_rewards(self):
        print(self.class_reward)
    
    def restart(self):
        self.cur_pos_x, self.cur_pos_y = self.start_coord
        self.objects_so_far = [0] * self.n_o
        return self.start_coord
        
    def step(self, action):
        flag = 1
        reward = 0
        phi_at_step = [0] * (self.n_c + 1)
        done = False
        if action == 0 and self.cur_pos_y + 1 < self.ht:
            self.cur_pos_y += 1
        elif action == 1 and self.cur_pos_x + 1 < self.wd:
            self.cur_pos_x += 1
        elif action == 2 and self.cur_pos_y - 1 >=0:
            self.cur_pos_y -= 1
        elif action == 3 and self.cur_pos_x - 1 >=0:
            self.cur_pos_x -= 1
        
        pos = (self.cur_pos_x, self.cur_pos_y)
        if pos == self.goal_coord:
            phi_at_step[-1] = self.r_g
            done = True
            reward += 1
        elif pos in self.object_coord:
            object_index = self.object_coord.index(pos)
            if self.objects_so_far[object_index] == 0:
                phi_at_step[self.object_class[object_index]] = 1
                self.objects_so_far[object_index] = 1
                reward += self.class_reward[self.object_class[object_index]]

        return pos, np.array(phi_at_step), reward, done

# %%
class RadialBasis():

    def __init__(self, x_dim, y_dim, basis_x, basis_y):

        self.centres = []
        self.x_dim, self.y_dim = x_dim, y_dim
        for x in np.linspace(0, x_dim, basis_x):
            for y in np.linspace(0, y_dim, basis_y):
                self.centres.append((x/x_dim, y/y_dim))
      
    def getPositionVector(self, x, y):
        state = []
        x,y = x/self.x_dim, y/self.y_dim
        for cx, cy in self.centres:
            state.append(np.exp(-1 * ((cx - x)**2 + (cy - y)**2)/0.1))
        return np.array(state)

# %%
class QL:
    def __init__(self, env):
        self.env = env
        self.reward_weight_list = []
        self.z_list = []
        self.eps_greedy = 0.15
        self.gamma = 0.95
        self.num_steps = 10000
        self.alpha = 0.01
        self.rdb = RadialBasis(env.wd, env.ht, 10, 10)
        self.cum_reward_list = []

    def featurize_state(self, state):
        return np.hstack((self.rdb.getPositionVector(state[0], state[1]), np.array(self.env.objects_so_far)))
    
    def find_q_val(self, small_phi, z):
        max_k = 0
        action_val = -999999
        
        
        for action in self.env.actions: 
            new_action_val = np.dot(small_phi.T,z[action])
            action_val = max(action_val,new_action_val)
        
        return action_val
        
        
        return max_k 
                
    def get_action(self, small_phi, z):
        if np.random.uniform(0,1) < self.eps_greedy:   #In paper, Bernoulli is considered imstead of uniform
            return np.random.choice(self.env.actions)
        else:
            val_his = -99999
            act_choice = 0
            for action in self.env.actions:
                val = np.dot(small_phi.T, z[action])
                act_choice = action if val > val_his else act_choice
                val_his = max(val_his,val)
            return act_choice

    
    
    def algorithm(self,num_tasks):
        D = self.env.D
        d = self.env.d
        
        NUM_STEPS = self.num_steps
        
        
        for t in range(0, num_tasks):
            z = [np.random.rand(D) for r in range(len(self.env.actions))]
            print("Task: ",t)
            #self.z_list.append(deepcopy(z))
            env.reset()

            cum_reward = 0
            new_episode = True
            for ep in range(NUM_STEPS):
                if new_episode == True:
                    gamma = self.gamma
                    state = self.env.restart()
                    done = False
                    #creward = 0
                    new_episode = False
                
                small_phi = self.featurize_state(state)
                
                action = self.get_action(small_phi, z)
                s_prime, phi_at_step, reward, done = self.env.step(action)

                
                small_phi_prime = self.featurize_state(s_prime)

                if done:
                    gamma = 0
                    new_episode = True
               
                
                cum_reward += reward
                self.cum_reward_list.append(cum_reward)
                
                #z[action] = z[action] + self.alpha * (reward - np.dot(phi_at_step.T, w_t)) * phi_at_step
                q_prime_sa = self.find_q_val(small_phi_prime.T, z)
                q_sa = np.dot(small_phi.T, z[action])
                z_a = z[action]
               
                target = reward + gamma * q_prime_sa
                z_a = z_a + self.alpha * (target  - q_sa) * small_phi


                state = s_prime
                #print(round(cum_reward,4),end = " ")
            
            #mavg += creward
            print("Final",round(cum_reward,4))
        
        self.plot(cum_reward_list,num_tasks)
        return self.cum_reward_list
    
    def plot(self,cum_reward_list,num_talks):
        x_size = self.num_steps * num_talks
        x_axis = list(range(1,x_size+1))
        y_axis = cum_reward_list
        plt.plot(x_axis,y_axis)
        plt.xlabel("steps")
        plt.ylabel("cumulative reward")
        plt.title("QL")
        plt.legend()
        plt.show()

# %%
env = GridWorld(10, 10, 3, 10)
a = QL(env)
cum_reward_list = a.algorithm(250)
# Out:
# Task:  0
# Final -4.4491
# Task:  1
# Final 0.4017
# Task:  2
# Final 0.406
# Task:  3
# Final 37.6188
# Task:  4
# Final 3.0991
# Task:  5
# Final 2.3357
# Task:  6
# Final -0.864
# Task:  7
# Final 13.0928
# Task:  8
# Final -2.7279
# Task:  9
# Final 1.2611
# Task:  10
# Final 0.253
# Task:  11
# Final -1.7406
# Task:  12
# Final -6.7203
# Task:  13
# Final 3.8392
# Task:  14
# Final -2.6895
# Task:  15
# Final -0.2185
# Task:  16
# Final 38.7862
# Task:  17
# Final 14.7844
# Task:  18
# Final 2.2166
# Task:  19
# Final -4.2212
# Task:  20
# Final 0.0894
# Task:  21
# Final 0.1741
# Task:  22
# Final 14.6153
# Task:  23
# Final 1.0317
# Task:  24
# Final 0.9762
# Task:  25
# Final 2.3795
# Task:  26
# Final -0.6412
# Task:  27
# Final -0.4007
# Task:  28
# Final -0.2016
# Task:  29
# Final 28.8102
# Task:  30
# Final -5.6854
# Task:  31
# Final 0.1934
# Task:  32
# Final 1.8602
# Task:  33
# Final 0.9965
# Task:  34
# Final -0.1387
# Task:  35
# Final -0.2009
# Task:  36
# Final -2.3511
# Task:  37
# Final 0.9794
# Task:  38
# Final 19.848
# Task:  39
# Final 0.7671
# Task:  40
# Final 0.0589
# Task:  41
# Final -13.5465
# Task:  42
# Final 1.2602
# Task:  43
# Final -9.5069
# Task:  44
# Final 0.3427
# Task:  45
# Final -0.1544
# Task:  46
# Final -0.4581
# Task:  47
# Final -2.9442
# Task:  48
# Final -18.6141
# Task:  49
# Final 9.4445
# Task:  50
# Final -0.4818
# Task:  51
# Final 0.1944
# Task:  52
# Final 0.3871
# Task:  53
# Final 1.1887
# Task:  54
# Final 24.9925
# Task:  55
# Final -1.3966
# Task:  56
# Final 0.594
# Task:  57
# Final 247.1085
# Task:  58
# Final 1.884
# Task:  59
# Final -1.0978
# Task:  60
# Final 0.1785
# Task:  61
# Final 0.5593
# Task:  62
# Final 8.8117
# Task:  63
# Final -1.4316
# Task:  64
# Final 5.2991
# Task:  65
# Final 7.4933
# Task:  66
# Final 0.2025
# Task:  67
# Final -0.7831
# Task:  68
# Final 0.6484
# Task:  69
# Final 0.6119
# Task:  70
# Final -0.5331
# Task:  71
# Final -5.1412
# Task:  72
# Final 0.7754
# Task:  73
# Final 0.0319
# Task:  74
# Final 0.0415
# Task:  75
# Final -21.4106
# Task:  76
# Final -1.612
# Task:  77
# Final -0.5782
# Task:  78
# Final -2.1218
# Task:  79
# Final -3.2086
# Task:  80
# Final 35.5047
# Task:  81
# Final 1.8032
# Task:  82
# Final 9.1974
# Task:  83
# Final 8.8004
# Task:  84
# Final 16.9236
# Task:  85
# Final -2.5517
# Task:  86
# Final 0.3039
# Task:  87
# Final 99.2729
# Task:  88
# Final 3.96
# Task:  89
# Final 2.209
# Task:  90
# Final -1.1008
# Task:  91
# Final 0
# Task:  92
# Final 2.4663
# Task:  93
# Final 31.7367
# Task:  94
# Final 1.6184
# Task:  95
# Final 0.1949
# Task:  96
# Final -1.656
# Task:  97
# Final 4.0903
# Task:  98
# Final -1.6522
# Task:  99
# Final 5.3421
# Task:  100
# Final -0.1897
# Task:  101
# Final -3.1453
# Task:  102
# Final -1.3687
# Task:  103
# Final 2.2173
# Task:  104
# Final 1.2688
# Task:  105
# Final 23.0858
# Task:  106
# Final 0.2458
# Task:  107
# Final 45.64
# Task:  108
# Final 3.048
# Task:  109
# Final 16.2443
# Task:  110
# Final 23.4104
# Task:  111
# Final 0.0971
# Task:  112
# Final -2.2144
# Task:  113
# Final 0.8083
# Task:  114
# Final -0.9116
# Task:  115
# Final -0.7711
# Task:  116
# Final -0.9573
# Task:  117
# Final -0.2138
# Task:  118
# Final -1.1661
# Task:  119
# Final -0.0174
# Task:  120
# Final -1.119
# Task:  121
# Final -0.7149
# Task:  122
# Final 8.5279
# Task:  123
# Final 0.7524
# Task:  124
# Final 0.0563
# Task:  125
# Final 1.1568
# Task:  126
# Final 0.3819
# Task:  127
# Final 2.8446
# Task:  128
# Final 0.2001
# Task:  129
# Final 0.8054
# Task:  130
# Final -0.9363
# Task:  131
# Final 1.5213
# Task:  132
# Final -1.3718
# Task:  133
# Final -0.3857
# Task:  134
# Final 0.1087
# Task:  135
# Final -0.4037
# Task:  136
# Final 0.2684
# Task:  137
# Final -1.2886
# Task:  138
# Final 26.8619
# Task:  139
# Final 10.9158
# Task:  140
# Final -1.3623
# Task:  141
# Final 1.8955
# Task:  142
# Final -0.3767
# Task:  143
# Final 9.2799
# Task:  144
# Final -2.0894
# Task:  145
# Final 4.7289
# Task:  146
# Final 38.7855
# Task:  147
# Final 3.5902
# Task:  148
# Final -5.9425
# Task:  149
# Final -0.4275
# Task:  150
# Final 1.3577
# Task:  151
# Final 21.1199
# Task:  152
# Final -0.6219
# Task:  153
# Final -0.5108
# Task:  154
# Final 0.7266
# Task:  155
# Final 8.9089
# Task:  156
# Final 0.098
# Task:  157
# Final 0.8594
# Task:  158
# Final -0.3345
# Task:  159
# Final 4.4764
# Task:  160
# Final -2.0897
# Task:  161
# Final -8.163
# Task:  162
# Final -0.2311
# Task:  163
# Final -3.0594
# Task:  164
# Final -0.1141
# Task:  165
# Final -1.3727
# Task:  166
# Final 7.8038
# Task:  167
# Final -0.4292
# Task:  168
# Final -10.0107
# Task:  169
# Final 0.9795
# Task:  170
# Final -1.3259
# Task:  171
# Final 12.7506
# Task:  172
# Final 1.4792
# Task:  173
# Final -0.1016
# Task:  174
# Final -1.8886
# Task:  175
# Final 14.1393
# Task:  176
# Final -0.6829
# Task:  177
# Final 1.7649
# Task:  178
# Final 0.9549
# Task:  179
# Final -0.4221
# Task:  180
# Final 8.5988
# Task:  181
# Final -0.3464
# Task:  182
# Final -15.3456
# Task:  183
# Final 1.5347
# Task:  184
# Final 0.7201
# Task:  185
# Final -0.2162
# Task:  186
# Final -0.4446
# Task:  187
# Final 4.1488
# Task:  188
# Final 5.069
# Task:  189
# Final -25.6331
# Task:  190
# Final 12.4844
# Task:  191
# Final 0.8108
# Task:  192
# Final 1.6561
# Task:  193
# Final 8.4562
# Task:  194
# Final -2.0664
# Task:  195
# Final 10.8479
# Task:  196
# Final 0.1085
# Task:  197
# Final -0.4978
# Task:  198
# Final 0.5838
# Task:  199
# Final -10.031
# Task:  200
# Final -2.2707
# Task:  201
# Final -3.3866
# Task:  202
# Final 37.4155
# Task:  203
# Final -0.5138
# Task:  204
# Final -9.2339
# Task:  205
# Final 0.7888
# Task:  206
# Final 5.6576
# Task:  207
# Final -4.6634
# Task:  208
# Final 0.5172
# Task:  209
# Final 0.2674
# Task:  210
# Final 2.873
# Task:  211
# Final -0.3446
# Task:  212
# Final -1.4946
# Task:  213
# Final -11.735
# Task:  214
# Final 2.0135
# Task:  215
# Final 0.3705
# Task:  216
# Final 0.3127
# Task:  217
# Final 0.5634
# Task:  218
# Final -0.1511
# Task:  219
# Final -1.0318
# Task:  220
# Final 0.3555
# Task:  221
# Final -0.254
# Task:  222
# Final -0.3393
# Task:  223
# Final 1.8733
# Task:  224
# Final -0.7903
# Task:  225
# Final -1.1746
# Task:  226
# Final 23.0209
# Task:  227
# Final 12.4973
# Task:  228
# Final 1.8587
# Task:  229
# Final 1.1023
# Task:  230
# Final -0.2242
# Task:  231
# Final 5.55
# Task:  232
# Final -2.6067
# Task:  233
# Final 0.2498
# Task:  234
# Final -0.9294
# Task:  235
# Final 2.0277
# Task:  236
# Final 0.1924
# Task:  237
# Final -0.513
# Task:  238
# Final -1.5783
# Task:  239
# Final 25.5552
# Task:  240
# Final 0.9797
# Task:  241
# Final 4.0768
# Task:  242
# Final 29.8451
# Task:  243
# Final -0.0587
# Task:  244
# Final 3.4115
# Task:  245
# Final 2.4394
# Task:  246
# Final 7.1162
# Task:  247
# Final -1.8015
# Task:  248
# Final -3.4786
# Task:  249
# Final -0.9641
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9486886ce3c6> in <module>
#       1 env = GridWorld(10, 10, 3, 10)
#       2 a = QL(env)
# ----> 3 cum_reward_list = a.algorithm(250)
#
# <ipython-input-8-ca4fd8cd37df> in algorithm(self, num_tasks)
#      96             print("Final",round(cum_reward,4))
#      97
# ---> 98         self.plot(cum_reward_list,num_tasks)
#      99         return self.cum_reward_list
#     100
#
# NameError: name 'cum_reward_list' is not defined

# %%
plot(a.cum_reward_list,250)
# Out:
# No handles with labels found to put in legend.

# %%
file = open('cum_reward_list_ql', 'wb')
pickle.dump(a.cum_reward_list, file)
file.close()

# %%
def plot(cum_reward_list,num_talks):
        x_size = 10000 * num_talks
        x_axis = list(range(1,x_size+1))
        y_axis = cum_reward_list
        plt.plot(x_axis,y_axis)
        plt.xlabel("steps")
        plt.ylabel("cumulative reward")
        plt.title("QL")
        plt.legend()
        plt.show()

# %%
file = open('cum_reward_list_ql', 'rb')
cum_reward = pickle.load(file)
file.close()

# %%
print(a.cum_reward_list)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
cum_reward
# Out:
# [0,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.32446578721121977,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  -0.7454750320959758,
#  ...]

# %%
def graphPlot(x, y, xl, yl, title):
    #plt.figure(figsize=(2,10))
    plt.plot(x, y)
    plt.xlabel(xl)
    plt.ylabel(yl)
    plt.legend()
    plt.title(title)
    plt.show()

# %%
x = [i for i in range(100)]
plt.plot(x, cr2, label = "SFQL")
plt.plot(x, cr3, label = "QL(Function Approximation)")
plt.xlabel("Tasks")
plt.ylabel("Cumuative Returns")
plt.legend()
plt.title(title)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7113738f3c1b> in <module>
#       1 x = [i for i in range(100)]
# ----> 2 plt.plot(x, cr2, label = "SFQL")
#       3 plt.plot(x, cr3, label = "QL(Function Approximation)")
#       4 plt.xlabel("Tasks")
#       5 plt.ylabel("Cumuative Returns")
#
# NameError: name 'cr2' is not defined
